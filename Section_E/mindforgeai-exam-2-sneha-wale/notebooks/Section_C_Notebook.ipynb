# %%
import pandas as pd

# =====================================================================
# TASK 1 & 2: Load Dataset and Data Audit (With Robust Delimiter & Space Fix)
# =====================================================================
print("--- TASK 1 & 2: DATA LOADING & AUDIT ---")

# sep=None automatically detects tabs (\t) or commas (,)
df = pd.read_csv('week_2_3_exam_student_signals.csv', sep=None, engine='python')

# Strip any hidden whitespaces or tab characters from the column names
df.columns = df.columns.str.strip()

# Print metrics to verify it successfully loaded all 8 columns
print(f"Dataset Shape: {df.shape[0]} rows, {df.shape[1]} columns")
print("\nVerified Column Names:", list(df.columns))
print("\nData Types:")
print(df.dtypes)
print("\nMissing Values Count:")
print(df.isnull().sum())
print("\nFirst Rows of Processed Data:")
print(df.head())

# =====================================================================
# TASK 3: Readiness Score Engine Function
# =====================================================================
print("\n" + "="*50 + "\n--- TASK 3: APPLYING READINESS SCORE ENGINE ---")
def calculate_readiness(row):
    # Dynamic Weightage: Attendance (20%), Tasks (30%), Assignment (25%), Lab (25%)
    score = (row['attendance_pct'] * 0.20) + \
            (row['tasks_completed'] * 3.0) + \
            (row['assignment_score'] * 0.25) + \
            (row['lab_score'] * 0.25)
    return min(score, 100) # Capped at 100%

# Generate final_score calculation
df['final_score'] = df.apply(calculate_readiness, axis=1)
print(df[['name', 'final_score']])

# =====================================================================
# TASK 4: Classification Logic
# =====================================================================
print("\n" + "="*50 + "\n--- TASK 4: CLASSIFYING PERFORMANCE BANDS ---")
def classify_band(score):
    if score >= 90: return 'Excellent'
    elif score >= 70: return 'Strong'
    elif score >= 40: return 'Developing'
    else: return 'Support'

# Generate performance bands
df['band'] = df['final_score'].apply(classify_band)
print(df[['name', 'final_score', 'band']])

# =====================================================================
# TASK 5: Analytics Outputs
# =====================================================================
print("\n" + "="*50 + "\n--- TASK 5: GENERATING ANALYTICS INSIGHTS ---")

# 1. Department Performance Metric
print("1. Department Average Scores:")
print(df.groupby('department')['final_score'].mean())

# 2. Top Performer Identification
top_student = df.loc[df['final_score'].idxmax()]
print(f"\n2. Top Performer: {top_student['name']} ({top_student['final_score']:.2f}%)")

# 3. Targeted Support/Intervention List
support_list = df[df['band'] == 'Support']
print("\n3. Students Needing Support:")
if not support_list.empty:
    print(support_list[['name', 'department', 'final_score']])
else:
    print("None! All students scored above the support threshold.")
# Out:
# --- TASK 1 & 2: DATA LOADING & AUDIT ---
# Dataset Shape: 8 rows, 1 columns
#
# Data Types:
# student_id\tname\tdepartment\tattendance_pct\tdiary_entries\ttasks_completed\tassignment_score\tlab_score    str
# dtype: object
#
# Missing Values Count:
# student_id\tname\tdepartment\tattendance_pct\tdiary_entries\ttasks_completed\tassignment_score\tlab_score    0
# dtype: int64
#
# First Rows of Data:
#   student_id\tname\tdepartment\tattendance_pct\tdiary_entries\ttasks_completed\tassignment_score\tlab_score
# 0  2026CS001\tAditi\tComputer Engineering\t92\t12...
# 1  2026CS002\tBhavana\tComputer Engineering\t64\t...
# 2  2026IT001\tChaitra\tInformation Technology\t78...
# 3  2026IT002\tDivya\tInformation Technology\t55\t...
# 4  2026CE001\tEsha\tCivil Engineering\t88\t10\t8\...
#
# ==================================================
# --- TASK 3: APPLYING READINESS SCORE ENGINE ---
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
# --> 197 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7668 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
# -> 7676 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 'attendance_pct'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[2], line 32
#      28             (row['lab_score'] * 0.25)
#      29     return min(score, 100) # Safeguard cap at 100%
#      30
#      31 # Create the final_score column
# ---> 32 df['final_score'] = df.apply(calculate_readiness, axis=1)
#      33 print(df[['name', 'final_score']])
#      34
#      35 # =====================================================================
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:12435, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   12431                 engine_kwargs=engine_kwargs,
#   12432                 args=args,
#   12433                 kwargs=kwargs,
#   12434             )
# > 12435             return op.apply().__finalize__(self, method="apply")
#   12436         elif hasattr(engine, "__pandas_udf__"):
#   12437             if result_type is not None:
#   12438                 raise NotImplementedError(
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1015, in FrameApply.apply(self)
#    1012 elif self.raw:
#    1013     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# -> 1015 return self.apply_standard()
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1167, in FrameApply.apply_standard(self)
#    1165 def apply_standard(self):
#    1166     if self.engine == "python":
# -> 1167         results, res_index = self.apply_series_generator()
#    1168     else:
#    1169         results, res_index = self.apply_series_numba()
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\apply.py:1183, in FrameApply.apply_series_generator(self)
#    1180 results = {}
#    1182 for i, v in enumerate(series_gen):
# -> 1183     results[i] = self.func(v, *self.args, **self.kwargs)
#    1184     if isinstance(results[i], ABCSeries):
#    1185         # If we have a view on v, we need to make a copy because
#    1186         #  series_generator will swap out the underlying data
#    1187         results[i] = results[i].copy(deep=False)
#
# Cell In[2], line 25, in calculate_readiness(row)
#      23 def calculate_readiness(row):
#      24     # Logical Weightage: Attendance (20%), Tasks (30%), Assignment (25%), Lab (25%)
# ---> 25     score = (row['attendance_pct'] * 0.20) + \
#      26             (row['tasks_completed'] * 3.0) + \
#      27             (row['assignment_score'] * 0.25) + \
#      28             (row['lab_score'] * 0.25)
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File c:\Users\Sneha\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'attendance_pct'
